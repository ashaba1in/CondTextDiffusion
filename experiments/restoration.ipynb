# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys

sys.path.append("/home/vmeshchaninov/DiffusionTextGeneration/")

# %%
import torch
import numpy as np
import ml_collections
import matplotlib.pyplot as plt

from tqdm import tqdm
from torch.utils.data import DataLoader
from diffusion_holder import DiffusionRunner
from transformers import BertConfig, BertTokenizerFast

from data.create_dataset import create_wikipedia_dataset, create_rocstory_dataset, create_glue_unsupervised_dataset
from data.preprocessing import text_preprocessor, unsupervised_preprocessor, supervised_preprocessor
from utils.util import dict_to_tensors, masked_mean, masked_std, set_seed, dict_to_cuda
from estimation_utils.util import clear_text, compute_metric
from estimation_utils.metrics import BloomMetric

# %%
def create_config():
    config = ml_collections.ConfigDict()

    training = config.training = ml_collections.ConfigDict()
    training.ode_sampling = False
    training.checkpoints_folder = '../checkpoints'
    checkpoints_prefix = ""
    
    sde = config.sde = ml_collections.ConfigDict()
    sde.typename = 'vp-sde'
    sde.solver = 'euler'
    sde.N = 2000
    sde.beta_min = 0.1
    sde.beta_max = 20
    sde.ode_sampling = False

    model = config.model = ml_collections.ConfigDict()
    model.ema_rate = 0.9999
    model.enc_type = "base"
    model.embeddings_type = "encodings"
    model.dif_enc_type = "base"
    model.prediction = "x_0"
    model.dataset = "rocstory"

    data = config.data = ml_collections.ConfigDict()
    data.config_path = "/home/vmeshchaninov/DiffusionTextGeneration/data/config.json"
    data.max_sequence_len = 32

    config.device = 'cuda:0'
    config.ddp = False
    config.seed = 0
    config.bert_config = None
    return config

# %%
config = create_config()
config.checkpoints_prefix = "rocstory--encodings-prediction=x_0-loss=L_x_0-enc=base-bert=base-kl_cf=0.0-seq_len=32-clipgrad=0.2-lr=0.0002-min_lr=0.0002-new_net_v1.3_time_norm_1000000_"
config.lin_input = True
config.bert_config = BertConfig.from_pretrained("bert-base-uncased")

seed = config.seed
set_seed(seed)

diffusion_old = DiffusionRunner(config, latent_mode="encodings", eval=True)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertLMHeadModel: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertLMHeadModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertLMHeadModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
config = create_config()
config.checkpoints_prefix = "rocstory--encodings-prediction=x_0-loss=L_x_0-enc=base-bert=base-kl_cf=0.0-seq_len=32-clipgrad=0.2-lr=0.0002-min_lr=0.0002-new_net_v1.3.4-woinputproj_1000000_"
config.lin_input = False
config.bert_config = BertConfig.from_pretrained("bert-base-uncased")

seed = config.seed
set_seed(seed)

diffusion_new = DiffusionRunner(config, latent_mode="encodings", eval=True)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertLMHeadModel: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertLMHeadModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertLMHeadModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
metric_bloom_fn = BloomMetric(device=f"cuda:0")

# %%
max_sequence_len = 32
tokenizer = BertTokenizerFast.from_pretrained("bert-base-uncased")
dataset_roc = create_rocstory_dataset(split="validation", tokenizer=tokenizer, max_sequence_len=max_sequence_len)

# %%
batch_size = 32
loader = DataLoader(
            dataset_roc,
            batch_size=batch_size,
            num_workers=1,
            shuffle=False,
        )


for X in loader:
    break
X = dict_to_cuda(X)

# %%
embs = diffusion_old.sampler_emb({key:X[key].cuda() for key in ["input_ids", "attention_mask"]})
mask = X["attention_mask"]
torch.mean(masked_mean(embs, mask)), torch.mean(masked_std(embs, mask))
# Out:
# (tensor(0.0001, device='cuda:0'), tensor(1.0043, device='cuda:0'))

# %% [markdown]
# ## Эксперимент 1

# %%
@torch.no_grad()
def integrate_euler(diffusion, time_range, x_t):
    for t in tqdm(time_range):
        vec_t = t * torch.ones(batch_size, device="cuda:0")
        x_t = diffusion.diff_eq_solver.step(model=diffusion.score_estimator, x_t=x_t, t=vec_t)["x"]
    return x_t

# %%
eps_t = 1. / diffusion_old.diff_eq_solver.sde.N
timesteps = torch.linspace(diffusion_old.sde.T, eps_t, diffusion_old.sde.N, device=diffusion_old.device)

# %%
set_seed(seed)

batch_size = 32
shape = (
            batch_size,
            diffusion_old.config.data.max_sequence_len,
            diffusion_old.encoder.config.hidden_size
        )
x_t = diffusion_old.sde.prior_sampling(shape).to(diffusion_old.device)

# %%
n = 0
x_t = integrate_euler(diffusion_old, timesteps[:n], x_t)
x = integrate_euler(diffusion_new, timesteps[n:], x_t)
# Out:
# 0it [00:00, ?it/s]
#  23%|██▎       | 463/2000 [00:07<00:24, 61.79it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [61], in <cell line: 3>()
#       1 n = 0
#       2 x_t = integrate_euler(diffusion_old, timesteps[:n], x_t)
# ----> 3 x = integrate_euler(diffusion_new, timesteps[n:], x_t)
#
# File ~/anaconda3/envs/env/lib/python3.9/site-packages/torch/autograd/grad_mode.py:27, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      24 @functools.wraps(func)
#      25 def decorate_context(*args, **kwargs):
#      26     with self.clone():
# ---> 27         return func(*args, **kwargs)
#
# Input In [37], in integrate_euler(diffusion, time_range, x_t)
#       3 for t in tqdm(time_range):
#       4     vec_t = t * torch.ones(batch_size, device="cuda:0")
# ----> 5     x_t = diffusion.diff_eq_solver.step(model=diffusion.score_estimator, x_t=x_t, t=vec_t)["x"]
#       6 return x_t
#
# File ~/DiffusionTextGeneration/diffusion_utils/diffusion_dynamic_sde.py:204, in EulerDiffEqSolver.step(self, model, x_t, t)
#     202 dt = -1. / self.rsde.N
#     203 z = torch.randn_like(x_t)
# --> 204 rsde_params = self.rsde.sde(model, x_t, t)
#     205 drift, diffusion = rsde_params['drift'], rsde_params['diffusion']
#     206 x_mean = x_t + drift * dt
#
# File ~/DiffusionTextGeneration/diffusion_utils/diffusion_dynamic_sde.py:139, in DDPM_SDE.reverse.<locals>.RSDE.sde(self, model, x_t, t)
#     136 sde_params = sde_cls.sde(x_t, t)
#     137 drift_par, diffusion = sde_params['drift'], sde_params['diffusion']  # -1/2 * beta * x_t, sqrt(beta)
# --> 139 scores = sde_cls.calc_score(model, x_t, t)
#     140 score = scores['score']
#     141 drift = drift_par - diffusion[:, None, None] ** 2 * score * (0.5 if self.ode_sampling else 1.)
#
# File ~/DiffusionTextGeneration/diffusion_utils/diffusion_dynamic_sde.py:164, in DDPM_SDE.calc_score(self, model, x_t, t, mask)
#     161 params = self.marginal_params_tensor(x_t, t)
#     163 if self.prediction == "x_0":
# --> 164     x_0 = model(x_t=x_t, time_t=t, attention_mask=mask)
#     165     eps_theta = (x_t - params["alpha"] * x_0) / params["std"]
#     166     score = -eps_theta / params["std"]
#
# File ~/anaconda3/envs/env/lib/python3.9/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/DiffusionTextGeneration/bert_model/score_estimator.py:227, in ScoreEstimatorEMB.forward(self, x_t, time_t, *args, **kwargs)
#     221 if attention_mask is not None:
#     222     attention_mask = self.get_extended_attention_mask(
#     223         attention_mask=attention_mask,
#     224         dtype=hidden_state.dtype
#     225     )
# --> 227 output = self.encoder(
#     228     hidden_state=hidden_state,
#     229     attention_mask=attention_mask,
#     230     emb_t=emb_t,
#     231     emb_x=emb_x,
#     232 ).last_hidden_state
#     234 output = self.output_down_proj(output).type(input_type)
#     235 #output = output.type(input_type)
#
# File ~/anaconda3/envs/env/lib/python3.9/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/DiffusionTextGeneration/bert_model/score_estimator.py:104, in BertEncoder.forward(self, hidden_state, attention_mask, emb_t, emb_x)
#     102     hidden_list.append(hidden_state)
#     103     hidden_state = self.norm_layers[i](hidden_state + self.time_layers[i](emb_t))
# --> 104     layer_outputs = layer(
#     105         hidden_state,
#     106         attention_mask,
#     107     )
#     108     hidden_state = layer_outputs[0]
#     110 for i, layer in enumerate(self.second_layers):
#
# File ~/anaconda3/envs/env/lib/python3.9/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/DiffusionTextGeneration/bert_model/score_estimator.py:53, in BertLayer.forward(self, hidden_states, attention_mask)
#      48 def forward(
#      49         self,
#      50         hidden_states: torch.Tensor,
#      51         attention_mask: Optional[torch.FloatTensor] = None,
#      52 ) -> Tuple[torch.Tensor]:
# ---> 53     self_attention_outputs = self.attention(
#      54         hidden_states,
#      55         attention_mask,
#      56     )
#      57     attention_output = self_attention_outputs[0]
#      59     outputs = self_attention_outputs[1:]
#
# File ~/anaconda3/envs/env/lib/python3.9/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/anaconda3/envs/env/lib/python3.9/site-packages/transformers/models/bert/modeling_bert.py:423, in BertAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     413 def forward(
#     414     self,
#     415     hidden_states: torch.Tensor,
#    (...)
#     421     output_attentions: Optional[bool] = False,
#     422 ) -> Tuple[torch.Tensor]:
# --> 423     self_outputs = self.self(
#     424         hidden_states,
#     425         attention_mask,
#     426         head_mask,
#     427         encoder_hidden_states,
#     428         encoder_attention_mask,
#     429         past_key_value,
#     430         output_attentions,
#     431     )
#     432     attention_output = self.output(self_outputs[0], hidden_states)
#     433     outputs = (attention_output,) + self_outputs[1:]  # add attentions if we output them
#
# File ~/anaconda3/envs/env/lib/python3.9/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/anaconda3/envs/env/lib/python3.9/site-packages/transformers/models/bert/modeling_bert.py:345, in BertSelfAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     342         relative_position_scores_key = torch.einsum("bhrd,lrd->bhlr", key_layer, positional_embedding)
#     343         attention_scores = attention_scores + relative_position_scores_query + relative_position_scores_key
# --> 345 attention_scores = attention_scores / math.sqrt(self.attention_head_size)
#     346 if attention_mask is not None:
#     347     # Apply the attention mask is (precomputed for all layers in BertModel forward() function)
#     348     attention_scores = attention_scores + attention_mask
#
# KeyboardInterrupt:

# %%
output = diffusion_old.pred_logits(x, None)
tokens = output.argmax(dim=-1)
text = diffusion_old.tokenizer.batch_decode(tokens)

# %%
text = clear_text(text)
compute_metric(metric_bloom_fn, text)
# Out:
# metric: bigscience/bloom-7b1, 3.7685: 100%|██████████| 32/32 [00:01<00:00, 19.18it/s]
# 3.768486860084922

# %%
dual_se_metric = dict()

# %%
for n in range(0, 2001, 200):
    set_seed(seed)

    batch_size = 256
    shape = (
                batch_size,
                diffusion_old.config.data.max_sequence_len,
                diffusion_old.encoder.config.hidden_size
            )
    x_t = diffusion_old.sde.prior_sampling(shape).to(diffusion_old.device)
    
    x_t = integrate_euler(diffusion_new, timesteps[:n], x_t) # Important lines
    x = integrate_euler(diffusion_old, timesteps[n:], x_t) # Important lines
    
    output = diffusion_old.pred_logits(x, None)
    tokens = output.argmax(dim=-1)
    text = diffusion_old.tokenizer.batch_decode(tokens)
    
    text = clear_text(text)
    dual_se_metric[n] = compute_metric(metric_bloom_fn, text)
# Out:
# 0it [00:00, ?it/s]
# 100%|██████████| 2000/2000 [03:38<00:00,  9.14it/s]
# metric: bigscience/bloom-7b1, 3.8317: 100%|██████████| 256/256 [00:13<00:00, 18.86it/s]
# 100%|██████████| 200/200 [00:21<00:00,  9.36it/s]
# 100%|██████████| 1800/1800 [03:15<00:00,  9.21it/s]
# metric: bigscience/bloom-7b1, 3.8237: 100%|██████████| 256/256 [00:12<00:00, 20.32it/s]
# 100%|██████████| 400/400 [00:42<00:00,  9.34it/s]
# 100%|██████████| 1600/1600 [02:53<00:00,  9.21it/s]
# metric: bigscience/bloom-7b1, 3.8290: 100%|██████████| 256/256 [00:12<00:00, 20.31it/s]
# 100%|██████████| 600/600 [01:04<00:00,  9.34it/s]
# 100%|██████████| 1400/1400 [02:31<00:00,  9.21it/s]
# metric: bigscience/bloom-7b1, 3.8174: 100%|██████████| 256/256 [00:12<00:00, 20.51it/s]
# 100%|██████████| 800/800 [01:25<00:00,  9.33it/s]
# 100%|██████████| 1200/1200 [02:10<00:00,  9.21it/s]
# metric: bigscience/bloom-7b1, 3.8747: 100%|██████████| 256/256 [00:12<00:00, 20.30it/s]
# 100%|██████████| 1000/1000 [01:47<00:00,  9.33it/s]
# 100%|██████████| 1000/1000 [01:48<00:00,  9.21it/s]
# metric: bigscience/bloom-7b1, 3.8741: 100%|██████████| 256/256 [00:12<00:00, 20.02it/s]
# 100%|██████████| 1200/1200 [02:08<00:00,  9.33it/s]
# 100%|██████████| 800/800 [01:26<00:00,  9.21it/s]
# metric: bigscience/bloom-7b1, 3.8588: 100%|██████████| 256/256 [00:12<00:00, 20.21it/s]
# 100%|██████████| 1400/1400 [02:30<00:00,  9.33it/s]
# 100%|██████████| 600/600 [01:05<00:00,  9.21it/s]
# metric: bigscience/bloom-7b1, 3.8642: 100%|██████████| 256/256 [00:12<00:00, 20.06it/s]
# 100%|██████████| 1600/1600 [02:51<00:00,  9.33it/s]
# 100%|██████████| 400/400 [00:43<00:00,  9.21it/s]
# metric: bigscience/bloom-7b1, 3.8676: 100%|██████████| 256/256 [00:12<00:00, 19.97it/s]
# 100%|██████████| 1800/1800 [03:13<00:00,  9.33it/s]
# 100%|██████████| 200/200 [00:21<00:00,  9.21it/s]
# metric: bigscience/bloom-7b1, 3.8594: 100%|██████████| 256/256 [00:12<00:00, 19.80it/s]
# 100%|██████████| 2000/2000 [03:34<00:00,  9.33it/s]
# 0it [00:00, ?it/s]
# metric: bigscience/bloom-7b1, 3.9142: 100%|██████████| 256/256 [00:12<00:00, 19.91it/s]

# %%
plt.figure(figsize=(15, 8))
plt.xlabel('time', fontsize=24)
plt.ylabel('bloom loss', fontsize=24)
#plt.title("norm x_t, dim=768", fontsize=24)

y = list(dual_se_metric.values())[::-1]
x = np.arange(0, 1.001, 0.1)

plt.plot(x, y)

# %%
plt.figure(figsize=(15, 8))
plt.xlabel('time', fontsize=24)
plt.ylabel('bloom loss', fontsize=24)
#plt.title("norm x_t, dim=768", fontsize=24)

x = sorted(list(dual_se_metric.keys()))
y = [dual_se_metric[i] for i in x]
x = [(2000 - i) / 2000 for i in x]

plt.plot(x, y)

# %%
n = 800
set_seed(seed)

batch_size = 256 * 8
shape = (
            batch_size,
            diffusion_old.config.data.max_sequence_len,
            diffusion_old.encoder.config.hidden_size
        )
x_t = diffusion_old.sde.prior_sampling(shape).to(diffusion_old.device)

x = integrate_euler(diffusion_new, timesteps, x_t)

output = diffusion_old.pred_logits(x, None)
tokens = output.argmax(dim=-1)
text = diffusion_old.tokenizer.batch_decode(tokens)

text = clear_text(text)
compute_metric(metric_bloom_fn, text)
# Out:
# 100%|██████████| 2000/2000 [25:56<00:00,  1.29it/s]
# metric: bigscience/bloom-7b1, 3.8721: 100%|██████████| 2048/2048 [01:41<00:00, 20.10it/s]
# 3.8721246539084

# %%
n = 1800
set_seed(seed)

batch_size = 256
shape = (
            batch_size,
            diffusion_old.config.data.max_sequence_len,
            diffusion_old.encoder.config.hidden_size
        )
x_t = diffusion_old.sde.prior_sampling(shape).to(diffusion_old.device)

x = integrate_euler(diffusion_old, timesteps[:n], x_t)

output = diffusion_old.pred_logits(x, None)
tokens = output.argmax(dim=-1)
text = diffusion_old.tokenizer.batch_decode(tokens)

text = clear_text(text)
compute_metric(metric_bloom_fn, text)
# Out:
# 100%|██████████| 1800/1800 [03:15<00:00,  9.22it/s]
# metric: bigscience/bloom-7b1, 3.8419: 100%|██████████| 256/256 [00:12<00:00, 20.39it/s]
# 3.8418600004674035

# %%
x = integrate_euler(diffusion_old, timesteps[n:], x)

output = diffusion_old.pred_logits(x, None)
tokens = output.argmax(dim=-1)
text = diffusion_old.tokenizer.batch_decode(tokens)

text = clear_text(text)
compute_metric(metric_bloom_fn, text)
# Out:
# 100%|██████████| 200/200 [00:21<00:00,  9.25it/s]
# metric: bigscience/bloom-7b1, 3.8317: 100%|██████████| 256/256 [00:12<00:00, 20.46it/s]
# 3.831672082277748
